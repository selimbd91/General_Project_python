# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df = pd.read_csv('time_series_covid19_confirmed_global.csv')
df.head(5)
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  7/2/20  7/3/20  7/4/20  7/5/20  7/6/20  \
# 0        0        0        0  ...   32022   32324   32672   32951   33190
# 1        0        0        0  ...    2662    2752    2819    2893    2964
# 2        0        0        0  ...   14657   15070   15500   15941   16404
# 3        0        0        0  ...     855     855     855     855     855
# 4        0        0        0  ...     315     328     346     346     346
#
#    7/7/20  7/8/20  7/9/20  7/10/20  7/11/20
# ...

# %%
print(df.shape)
# drop unwanted columns
df=df.drop(["Province/State","Lat","Long"], axis=1)
df
# Out:
# (266, 176)
#             Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0              Afghanistan        0        0        0        0        0
# 1                  Albania        0        0        0        0        0
# 2                  Algeria        0        0        0        0        0
# 3                  Andorra        0        0        0        0        0
# 4                   Angola        0        0        0        0        0
# ..                     ...      ...      ...      ...      ...      ...
# 261  Sao Tome and Principe        0        0        0        0        0
# 262                  Yemen        0        0        0        0        0
# 263                Comoros        0        0        0        0        0
# 264             Tajikistan        0        0        0        0        0
# 265                Lesotho        0        0        0        0        0
#
#      1/27/20  1/28/20  1/29/20  1/30/20  ...  7/2/20  7/3/20  7/4/20  7/5/20  \
# ...

# %%
# temperature = np.random.randint(low = 15, high= 35, size= (266, 1))
# df['Temperature'] = temperature
# df
# Out:
#             Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0              Afghanistan        0        0        0        0        0
# 1                  Albania        0        0        0        0        0
# 2                  Algeria        0        0        0        0        0
# 3                  Andorra        0        0        0        0        0
# 4                   Angola        0        0        0        0        0
# ..                     ...      ...      ...      ...      ...      ...
# 261  Sao Tome and Principe        0        0        0        0        0
# 262                  Yemen        0        0        0        0        0
# 263                Comoros        0        0        0        0        0
# 264             Tajikistan        0        0        0        0        0
# 265                Lesotho        0        0        0        0        0
#
#      1/27/20  1/28/20  1/29/20  1/30/20  ...  7/3/20  7/4/20  7/5/20  7/6/20  \
# ...

# %%
# change data from wide to long
df.set_index("Country/Region",inplace =True)
df=df.stack()
df
# Out:
# Country/Region
# Afghanistan     1/22/20      0
#                 1/23/20      0
#                 1/24/20      0
#                 1/25/20      0
#                 1/26/20      0
#                           ...
# Lesotho         7/7/20      91
#                 7/8/20      91
#                 7/9/20     134
#                 7/10/20    184
#                 7/11/20    184
# Length: 45752, dtype: int64

# %%
ddf = df.reset_index()
ddf.shape
ddf
# Out:
#       Country/Region  level_1    0
# 0        Afghanistan  1/22/20    0
# 1        Afghanistan  1/23/20    0
# 2        Afghanistan  1/24/20    0
# 3        Afghanistan  1/25/20    0
# 4        Afghanistan  1/26/20    0
# ...              ...      ...  ...
# 45747        Lesotho   7/7/20   91
# 45748        Lesotho   7/8/20   91
# 45749        Lesotho   7/9/20  134
# 45750        Lesotho  7/10/20  184
# 45751        Lesotho  7/11/20  184
#
# [45752 rows x 3 columns]

# %%
ddf.rename(columns={'Country/Region':'Country','level_1':'date',0:"cases"}, inplace =True)
ddf
# Out:
#            Country     date  cases
# 0      Afghanistan  1/22/20      0
# 1      Afghanistan  1/23/20      0
# 2      Afghanistan  1/24/20      0
# 3      Afghanistan  1/25/20      0
# 4      Afghanistan  1/26/20      0
# ...            ...      ...    ...
# 45747      Lesotho   7/7/20     91
# 45748      Lesotho   7/8/20     91
# 45749      Lesotho   7/9/20    134
# 45750      Lesotho  7/10/20    184
# 45751      Lesotho  7/11/20    184
#
# [45752 rows x 3 columns]

# %%
ddf.to_csv('COVID_2020.csv', index=False)

# %%
temperature = np.random.randint(low = 15, high= 35, size= (45752, 1))
ddf['Temperature'] = temperature
ddf
# Out:
#            Country     date  cases  Temperature
# 0      Afghanistan  1/22/20      0           15
# 1      Afghanistan  1/23/20      0           20
# 2      Afghanistan  1/24/20      0           26
# 3      Afghanistan  1/25/20      0           33
# 4      Afghanistan  1/26/20      0           33
# ...            ...      ...    ...          ...
# 45747      Lesotho   7/7/20     91           34
# 45748      Lesotho   7/8/20     91           24
# 45749      Lesotho   7/9/20    134           32
# 45750      Lesotho  7/10/20    184           22
# 45751      Lesotho  7/11/20    184           25
#
# [45752 rows x 4 columns]

# %%
ddf[ddf['Country'] == 'Lesotho']
# Out:
#        Country     date  cases
# 45580  Lesotho  1/22/20      0
# 45581  Lesotho  1/23/20      0
# 45582  Lesotho  1/24/20      0
# 45583  Lesotho  1/25/20      0
# 45584  Lesotho  1/26/20      0
# ...        ...      ...    ...
# 45747  Lesotho   7/7/20     91
# 45748  Lesotho   7/8/20     91
# 45749  Lesotho   7/9/20    134
# 45750  Lesotho  7/10/20    184
# 45751  Lesotho  7/11/20    184
#
# [172 rows x 3 columns]

# %%
temperature = np.random.randint(low = 15, high= 35, size= (266, 1))

# %%
df['Temperature'] = temperature
df
# Out:
#                    Country  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0              Afghanistan        0        0        0        0        0
# 1                  Albania        0        0        0        0        0
# 2                  Algeria        0        0        0        0        0
# 3                  Andorra        0        0        0        0        0
# 4                   Angola        0        0        0        0        0
# ..                     ...      ...      ...      ...      ...      ...
# 261  Sao Tome and Principe        0        0        0        0        0
# 262                  Yemen        0        0        0        0        0
# 263                Comoros        0        0        0        0        0
# 264             Tajikistan        0        0        0        0        0
# 265                Lesotho        0        0        0        0        0
#
#      1/27/20  1/28/20  1/29/20  1/30/20  ...  7/3/20  7/4/20  7/5/20  7/6/20  \
# ...

# %%
df.set_index("Country", inplace = True)
df=df.stack()
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-b0ed20434447> in <module>
# ----> 1 df.set_index("Country", inplace = True)
#       2 df=df.stack()
#       3 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'set_index'
